# %%
import numpy as np
import sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/forre/Desktop/Python/datasets/datasets-master/Life_Expectancy_Data.csv')

df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0              263
# 1     Afghanistan  2014  Developing              59.9              271
# 2     Afghanistan  2013  Developing              59.9              268
# 3     Afghanistan  2012  Developing              59.5              272
# 4     Afghanistan  2011  Developing              59.2              275
# ...           ...   ...         ...               ...              ...
# 1644     Zimbabwe  2004  Developing              44.3              723
# 1645     Zimbabwe  2003  Developing              44.5              715
# 1646     Zimbabwe  2002  Developing              44.8               73
# 1647     Zimbabwe  2001  Developing              45.3              686
# 1648     Zimbabwe  2000  Developing              46.0              665
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.rename(columns = {'Country' : 'country', 'Year' : 'year', 'Status' : 'status', 'Life expectancy ' : 'life expectancy', 'Adult Mortality' : 'adult mortality', 'Alcohol' : 'alcohol', 'Measles ' : 'Measles', ' BMI ' : 'BMI', 'under-five deaths ' : 'under-five deaths', 'Diphtheria ' : 'Diphtheria', ' HIV/AIDS' : 'HIV/AIDS'}, inplace = True)

# %%
df.columns
# Out:
# Index(['country', 'year', 'status', 'life expectancy', 'adult mortality',
#        'infant deaths', 'alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.corr()
# Out:
#                                      year  life expectancy  adult mortality  \
# year                             1.000000         0.050771        -0.037092
# life expectancy                  0.050771         1.000000        -0.702523
# adult mortality                 -0.037092        -0.702523         1.000000
# infant deaths                    0.008029        -0.169074         0.042450
# alcohol                         -0.113365         0.402718        -0.175535
# percentage expenditure           0.069553         0.409631        -0.237610
# Hepatitis B                      0.114897         0.199935        -0.105225
# Measles                         -0.053822        -0.068881        -0.003967
# BMI                              0.005739         0.542042        -0.351542
# under-five deaths                0.010479        -0.192265         0.060365
# Polio                           -0.016699         0.327294        -0.199853
# ...

# %%
df.head()
# Out:
#        country  year      status  life expectancy  adult mortality  \
# 0  Afghanistan  2015  Developing             65.0              263
# 1  Afghanistan  2014  Developing             59.9              271
# 2  Afghanistan  2013  Developing             59.9              268
# 3  Afghanistan  2012  Developing             59.5              272
# 4  Afghanistan  2011  Developing             59.2              275
#
#    infant deaths  alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624           65     1154  ...
# 1             64     0.01               73.523582           62      492  ...
# 2             66     0.01               73.219243           64      430  ...
# 3             69     0.01               78.184215           67     2787  ...
# 4             71     0.01                7.097109           68     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
X = df[['adult mortality', 'infant deaths', 'alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Schooling']]
y = df['life expectancy']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.25)

# %%
X_train.shape
# Out:
# (1236, 13)

# %%
X_test.shape
# Out:
# (413, 13)

# %%
life_exp = LinearRegression()

life_exp.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
life_exp.score(X_test, y_test)
# Out:
# 0.77378070012363

# %%
life_exp.score(X_train, y_train)
# Out:
# 0.8096427610926109

# %%
y_pred = life_exp.predict(X_test)

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 3.1073902482953044

# %%
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 16.92292641945473

# %%
print(life_exp.intercept_)
print(life_exp.coef_)
# Out:
# 51.88158305941219
# [-1.99210633e-02 -3.35847957e-03 -8.55033834e-02  3.96549655e-04
#  -1.09979000e-02  6.59498090e-06  8.29475803e-03  1.17340514e-01
#   3.05992447e-02 -4.48789396e-01  7.61800807e-06  1.79998063e-09
#   1.53553346e+00]

# %%
np.exp(life_exp.coef_)
# Out:
# array([0.98027605, 0.99664715, 0.91805004, 1.00039663, 0.98906236,
#        1.0000066 , 1.00832925, 1.12450227, 1.03107221, 0.63840053,
#        1.00000762, 1.        , 4.64380214])

# %%
mlpr = MLPRegressor(hidden_layer_sizes=(6, 2), max_iter=20000, random_state=42)

# %%
mlpr.fit(X_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(6, 2), max_iter=20000, random_state=42)

# %%
mlpr.score(X_train, y_train)
# Out:
# -0.00017478205370036193
